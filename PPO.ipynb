# %%
import omnisafe
from omnisafe.common.experiment_grid import ExperimentGrid
import wandb
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: sasank. Use `wandb login --relogin` to force relogin
# True

# %%
eg = ExperimentGrid(exp_name='PPO-benchmark')

# Set the algorithms.
unconstrained_policies = ['PPO']

# Set the environments.
safety_envs = [
    'SafetyPointGoal0-v0',
    'SafetyPointGoal1-v0',
    'SafetyPointGoal2-v0',
    'SafetyPointButton0-v0',
    'SafetyPointButton1-v0',
    'SafetyPointButton2-v0',
    'SafetyPointPush0-v0',
    'SafetyPointPush1-v0',
    'SafetyPointPush2-v0',
]
eg.add('env_id', safety_envs)
eg.add('algo', unconstrained_policies)
eg.add('logger_cfgs:use_wandb', [True])
eg.add('logger_cfgs:wandb_project', ['PPO_benchmark'])
eg.add('train_cfgs:vector_env_nums', [1])
eg.add('train_cfgs:torch_threads', [1])
eg.add('train_cfgs:total_steps', [2048*25])
eg.add('algo_cfgs:steps_per_epoch', [2048])
eg.add('algo_cfgs:gamma', [0.9, 0.95, 0.99])
eg.add('algo_cfgs:cost_gamma', [0.9, 0.95, 0.99])
eg.add('seed', [0,5,10])

# %%
"""Example of training a policy from exp-x config with OmniSafe."""
import os, sys
from omnisafe.typing import NamedTuple, Tuple


def train(
    exp_id: str, algo: str, env_id: str, custom_cfgs: NamedTuple
) -> Tuple[float, float, float]:
    """Train a policy from exp-x config with OmniSafe.

    Args:
        exp_id (str): Experiment ID.
        algo (str): Algorithm to train.
        env_id (str): The name of test environment.
        custom_cfgs (NamedTuple): Custom configurations.
        num_threads (int, optional): Number of threads. Defaults to 6.
    """
    terminal_log_name = 'terminal.log'
    error_log_name = 'error.log'
    if 'seed' in custom_cfgs:
        terminal_log_name = f'seed{custom_cfgs["seed"]}_{terminal_log_name}'
        error_log_name = f'seed{custom_cfgs["seed"]}_{error_log_name}'
    sys.stdout = sys.__stdout__
    sys.stderr = sys.__stderr__
    print(f'exp-x: {exp_id} is training...')
    if not os.path.exists(custom_cfgs['logger_cfgs']['log_dir']):
        os.makedirs(custom_cfgs['logger_cfgs']['log_dir'], exist_ok=True)
    # pylint: disable-next=consider-using-with
    sys.stdout = open(
        os.path.join(f'{custom_cfgs["logger_cfgs"]["log_dir"]}', terminal_log_name),
        'w',
        encoding='utf-8',
    )
    # pylint: disable-next=consider-using-with
    sys.stderr = open(
        os.path.join(f'{custom_cfgs["logger_cfgs"]["log_dir"]}', error_log_name),
        'w',
        encoding='utf-8',
    )
    agent = omnisafe.Agent(algo, env_id, custom_cfgs=custom_cfgs)
    reward, cost, ep_len = agent.learn()
    return reward, cost, ep_len

# %%
import torch
import warnings

# Set the device.
avaliable_gpus = [num for num in range(torch.cuda.device_count())]
print(avaliable_gpus)
gpu_id = [0]
# if you want to use CPU, please set gpu_id = None
# gpu_id = None

if set(gpu_id) > set(avaliable_gpus):
    warnings.warn('The GPU ID is not available, use CPU instead.')
    gpu_id = None
# Out:
# [0]

# %%
eg.run(train, 1, gpu_id=gpu_id)
# Out:
# Save with config of experiment grid in grid_config.json
# ================================================================================
# ExperimentGrid [PPO-benchmark] runs over parameters:
#  env_id
# [env]
#
# 	"SafetyPointGoal0-v0"
# 	"SafetyPointGoal1-v0"
# 	"SafetyPointGoal2-v0"
# 	"SafetyPointButton0-v0"
# 	"SafetyPointButton1-v0"
# 	"SafetyPointButton2-v0"
# 	"SafetyPointPush0-v0"
# 	"SafetyPointPush1-v0"
# 	"SafetyPointPush2-v0"
#  algo
# [alg]
#
# 	"PPO"
#  logger_cfgs:use_wandb
# [log-use]
#
# 	true
#  logger_cfgs:wandb_project
# [log-wan]
#
# 	"PPO_benchmark"
#  train_cfgs:vector_env_nums
# [tra-vec]
#
# 	1
#  train_cfgs:torch_threads
# [tra-tor]
#
# 	1
#  train_cfgs:total_steps
# [tra-tot]
#
# 	51200
#  algo_cfgs:steps_per_epoch
# [alg-ste]
#
# 	2048
#  algo_cfgs:gamma
# [alg-gam]
#
# 	0.9
# 	0.95
# 	0.99
#  algo_cfgs:cost_gamma
# [alg-cos]
#
# 	0.9
# 	0.95
# 	0.99
#  seed
# [see]
#
# 	0
# 	5
# 	10
#
#  Variants, counting seeds:               243
#  Variants, not counting seeds:           81
#
# ================================================================================
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key env_id
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048} key gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key env_id
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048} key gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key env_id
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048} key gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key env_id
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048} key gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key env_id
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048} key gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key env_id
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048} key gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key env_id
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048} key gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key env_id
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048} key gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key env_id
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048} key gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key env_id
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048} key gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key env_id
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048} key gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key env_id
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048} key gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key env_id
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048} key gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key env_id
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048} key gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key env_id
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048} key gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key env_id
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.99, 'gamma': 0.95, 'steps_per_epoch': 2048} key gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.99, 'gamma': 0.95, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key env_id
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.99, 'gamma': 0.95, 'steps_per_epoch': 2048} key gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.99, 'gamma': 0.95, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key env_id
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.99, 'gamma': 0.95, 'steps_per_epoch': 2048} key gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.99, 'gamma': 0.95, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.99, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key env_id
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.99, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.9, 'gamma': 0.99, 'steps_per_epoch': 2048} key gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.99, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.9, 'gamma': 0.99, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.99, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key env_id
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.99, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.9, 'gamma': 0.99, 'steps_per_epoch': 2048} key gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.99, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.9, 'gamma': 0.99, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.99, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key env_id
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.99, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.9, 'gamma': 0.99, 'steps_per_epoch': 2048} key gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.99, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.9, 'gamma': 0.99, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.99, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key env_id
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.99, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.95, 'gamma': 0.99, 'steps_per_epoch': 2048} key gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.99, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.95, 'gamma': 0.99, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.99, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key env_id
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.99, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.95, 'gamma': 0.99, 'steps_per_epoch': 2048} key gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.99, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.95, 'gamma': 0.99, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.99, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key env_id
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.99, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.95, 'gamma': 0.99, 'steps_per_epoch': 2048} key gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.99, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.95, 'gamma': 0.99, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.99, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key env_id
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.99, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.99, 'gamma': 0.99, 'steps_per_epoch': 2048} key gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.99, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.99, 'gamma': 0.99, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.99, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key env_id
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.99, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.99, 'gamma': 0.99, 'steps_per_epoch': 2048} key gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.99, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.99, 'gamma': 0.99, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.99, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key env_id
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.99, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.99, 'gamma': 0.99, 'steps_per_epoch': 2048} key gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.99, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.99, 'gamma': 0.99, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key env_id
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048} key gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key env_id
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048} key gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key env_id
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048} key gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key env_id
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048} key gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key env_id
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048} key gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key env_id
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048} key gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.95, 'gamma': 0.9, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key env_id
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048} key gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key env_id
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048} key gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key env_id
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048} key gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.99, 'gamma': 0.9, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key env_id
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048} key gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key env_id
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048} key gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key env_id
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048} key gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.9, 'gamma': 0.95, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key env_id
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048} key gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key env_id
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048} key gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key env_id
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048} key gamma
# value {'seed': 10, 'algo_cfgs': {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.95, 'gamma': 0.95, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key env_id
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:gamma
# value {'cost_gamma': 0.99, 'gamma': 0.95, 'steps_per_epoch': 2048} key gamma
# value {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key algo_cfgs:cost_gamma
# value {'cost_gamma': 0.99, 'gamma': 0.95, 'steps_per_epoch': 2048} key cost_gamma
# value {'seed': 5, 'algo_cfgs': {'cost_gamma': 0.99, 'gamma': 0.95, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal1-v0'} key env_id
# ...
# PPO-benchmark_envsafetypointbutton0-v0_alg-gam0-99_alg-cos0-9
# PPO-benchmark_envsafetypointbutton0-v0_alg-gam0-99_alg-cos0-95
# PPO-benchmark_envsafetypointbutton0-v0_alg-gam0-99_alg-cos0-99
# PPO-benchmark_envsafetypointbutton0-v0_alg-gam0-9_alg-cos0-9
# PPO-benchmark_envsafetypointbutton0-v0_alg-gam0-9_alg-cos0-95
# PPO-benchmark_envsafetypointbutton0-v0_alg-gam0-9_alg-cos0-99
# PPO-benchmark_envsafetypointbutton1-v0_alg-gam0-95_alg-cos0-9
# PPO-benchmark_envsafetypointbutton1-v0_alg-gam0-95_alg-cos0-95
# PPO-benchmark_envsafetypointbutton1-v0_alg-gam0-95_alg-cos0-99
# PPO-benchmark_envsafetypointbutton1-v0_alg-gam0-99_alg-cos0-9
# PPO-benchmark_envsafetypointbutton1-v0_alg-gam0-99_alg-cos0-95
# PPO-benchmark_envsafetypointbutton1-v0_alg-gam0-99_alg-cos0-99
# PPO-benchmark_envsafetypointbutton1-v0_alg-gam0-9_alg-cos0-9
# PPO-benchmark_envsafetypointbutton1-v0_alg-gam0-9_alg-cos0-95
# PPO-benchmark_envsafetypointbutton1-v0_alg-gam0-9_alg-cos0-99
# PPO-benchmark_envsafetypointbutton2-v0_alg-gam0-95_alg-cos0-9
# PPO-benchmark_envsafetypointbutton2-v0_alg-gam0-95_alg-cos0-95
# PPO-benchmark_envsafetypointbutton2-v0_alg-gam0-95_alg-cos0-99
# PPO-benchmark_envsafetypointbutton2-v0_alg-gam0-99_alg-cos0-9
# PPO-benchmark_envsafetypointbutton2-v0_alg-gam0-99_alg-cos0-95
# PPO-benchmark_envsafetypointbutton2-v0_alg-gam0-99_alg-cos0-99
# PPO-benchmark_envsafetypointbutton2-v0_alg-gam0-9_alg-cos0-9
# PPO-benchmark_envsafetypointbutton2-v0_alg-gam0-9_alg-cos0-95
# PPO-benchmark_envsafetypointbutton2-v0_alg-gam0-9_alg-cos0-99
# PPO-benchmark_envsafetypointgoal0-v0_alg-gam0-95_alg-cos0-9
# PPO-benchmark_envsafetypointgoal0-v0_alg-gam0-95_alg-cos0-95
# PPO-benchmark_envsafetypointgoal0-v0_alg-gam0-95_alg-cos0-99
# PPO-benchmark_envsafetypointgoal0-v0_alg-gam0-99_alg-cos0-9
# PPO-benchmark_envsafetypointgoal0-v0_alg-gam0-99_alg-cos0-95
# PPO-benchmark_envsafetypointgoal0-v0_alg-gam0-99_alg-cos0-99
# PPO-benchmark_envsafetypointgoal0-v0_alg-gam0-9_alg-cos0-9
# PPO-benchmark_envsafetypointgoal0-v0_alg-gam0-9_alg-cos0-95
# PPO-benchmark_envsafetypointgoal0-v0_alg-gam0-9_alg-cos0-99
# PPO-benchmark_envsafetypointgoal1-v0_alg-gam0-95_alg-cos0-9
# PPO-benchmark_envsafetypointgoal1-v0_alg-gam0-95_alg-cos0-95
# PPO-benchmark_envsafetypointgoal1-v0_alg-gam0-95_alg-cos0-99
# PPO-benchmark_envsafetypointgoal1-v0_alg-gam0-99_alg-cos0-9
# PPO-benchmark_envsafetypointgoal1-v0_alg-gam0-99_alg-cos0-95
# PPO-benchmark_envsafetypointgoal1-v0_alg-gam0-99_alg-cos0-99
# PPO-benchmark_envsafetypointgoal1-v0_alg-gam0-9_alg-cos0-9
# PPO-benchmark_envsafetypointgoal1-v0_alg-gam0-9_alg-cos0-95
# PPO-benchmark_envsafetypointgoal1-v0_alg-gam0-9_alg-cos0-99
# PPO-benchmark_envsafetypointgoal2-v0_alg-gam0-95_alg-cos0-9
# PPO-benchmark_envsafetypointgoal2-v0_alg-gam0-95_alg-cos0-95
# PPO-benchmark_envsafetypointgoal2-v0_alg-gam0-95_alg-cos0-99
# PPO-benchmark_envsafetypointgoal2-v0_alg-gam0-99_alg-cos0-9
# PPO-benchmark_envsafetypointgoal2-v0_alg-gam0-99_alg-cos0-95
# PPO-benchmark_envsafetypointgoal2-v0_alg-gam0-99_alg-cos0-99
# PPO-benchmark_envsafetypointgoal2-v0_alg-gam0-9_alg-cos0-9
# PPO-benchmark_envsafetypointgoal2-v0_alg-gam0-9_alg-cos0-95
# PPO-benchmark_envsafetypointgoal2-v0_alg-gam0-9_alg-cos0-99
# PPO-benchmark_envsafetypointpush0-v0_alg-gam0-95_alg-cos0-9
# PPO-benchmark_envsafetypointpush0-v0_alg-gam0-95_alg-cos0-95
# PPO-benchmark_envsafetypointpush0-v0_alg-gam0-95_alg-cos0-99
# PPO-benchmark_envsafetypointpush0-v0_alg-gam0-99_alg-cos0-9
# PPO-benchmark_envsafetypointpush0-v0_alg-gam0-99_alg-cos0-95
# PPO-benchmark_envsafetypointpush0-v0_alg-gam0-99_alg-cos0-99
# PPO-benchmark_envsafetypointpush0-v0_alg-gam0-9_alg-cos0-9
# PPO-benchmark_envsafetypointpush0-v0_alg-gam0-9_alg-cos0-95
# PPO-benchmark_envsafetypointpush0-v0_alg-gam0-9_alg-cos0-99
# PPO-benchmark_envsafetypointpush1-v0_alg-gam0-95_alg-cos0-9
# PPO-benchmark_envsafetypointpush1-v0_alg-gam0-95_alg-cos0-95
# PPO-benchmark_envsafetypointpush1-v0_alg-gam0-95_alg-cos0-99
# PPO-benchmark_envsafetypointpush1-v0_alg-gam0-99_alg-cos0-9
# PPO-benchmark_envsafetypointpush1-v0_alg-gam0-99_alg-cos0-95
# PPO-benchmark_envsafetypointpush1-v0_alg-gam0-99_alg-cos0-99
# PPO-benchmark_envsafetypointpush1-v0_alg-gam0-9_alg-cos0-9
# PPO-benchmark_envsafetypointpush1-v0_alg-gam0-9_alg-cos0-95
# PPO-benchmark_envsafetypointpush1-v0_alg-gam0-9_alg-cos0-99
# PPO-benchmark_envsafetypointpush2-v0_alg-gam0-95_alg-cos0-9
# PPO-benchmark_envsafetypointpush2-v0_alg-gam0-95_alg-cos0-95
# PPO-benchmark_envsafetypointpush2-v0_alg-gam0-95_alg-cos0-99
# PPO-benchmark_envsafetypointpush2-v0_alg-gam0-99_alg-cos0-9
# PPO-benchmark_envsafetypointpush2-v0_alg-gam0-99_alg-cos0-95
# PPO-benchmark_envsafetypointpush2-v0_alg-gam0-99_alg-cos0-99
# PPO-benchmark_envsafetypointpush2-v0_alg-gam0-9_alg-cos0-9
# PPO-benchmark_envsafetypointpush2-v0_alg-gam0-9_alg-cos0-95
# PPO-benchmark_envsafetypointpush2-v0_alg-gam0-9_alg-cos0-99
#
# ================================================================================
# current_config {'seed': 0, 'algo_cfgs': {'cost_gamma': 0.9, 'gamma': 0.9, 'steps_per_epoch': 2048}, 'train_cfgs': {'total_steps': 51200, 'torch_threads': 1, 'vector_env_nums': 1}, 'logger_cfgs': {'wandb_project': 'PPO_benchmark', 'use_wandb': True}, 'algo': 'PPO', 'env_id': 'SafetyPointGoal0-v0'}
# Logging data to
# ./exp-x\PPO-benchmark\SafetyPointGoal0-v0---b09b26ab57da024d77c978f293945933a184219a0388bd111061eef75822d804\PPO-{S
# afetyPointGoal0-v0}\seed-000-2024-04-21-00-00-42\progress.csv
# Save with config in config.json
# project PPO_benchmark name PPO-{SafetyPointGoal0-v0}-seed-000-2024-04-21-00-00-42
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>./exp-x\PPO-benchmark\SafetyPointGoal0-v0---b09b26ab57da024d77c978f293945933a184219a0388bd111061eef75822d804\PPO-{SafetyPointGoal0-v0}\seed-000-2024-04-21-00-00-42\wandb\run-20240421_000042-3tb26w60</code>
# Syncing run <strong><a href='https://wandb.ai/sasank/PPO_benchmark/runs/3tb26w60' target="_blank">PPO-{SafetyPointGoal0-v0}-seed-000-2024-04-21-00-00-42</a></strong> to <a href='https://wandb.ai/sasank/PPO_benchmark' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/sasank/PPO_benchmark' target="_blank">https://wandb.ai/sasank/PPO_benchmark</a>
#  View run at <a href='https://wandb.ai/sasank/PPO_benchmark/runs/3tb26w60' target="_blank">https://wandb.ai/sasank/PPO_benchmark/runs/3tb26w60</a>
# INFO: Start training
# c:\Users\saisa\.conda\envs\omnisafe-env\lib\site-packages\rich\live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# Warning: trajectory cut off when rollout by epoch at 48.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                       ┃ Value                 ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                 │ 0.03337051719427109   │
# │ Metrics/EpCost                │ 0.0                   │
# │ Metrics/EpLen                 │ 1000.0                │
# │ Train/Epoch                   │ 0.0                   │
# │ Train/Entropy                 │ 1.4062283039093018    │
# │ Train/KL                      │ 0.010632993653416634  │
# │ Train/StopIter                │ 40.0                  │
# │ Train/PolicyRatio/Mean        │ 1.0033260583877563    │
# │ Train/PolicyRatio/Min         │ 1.0033260583877563    │
# │ Train/PolicyRatio/Max         │ 1.0033260583877563    │
# │ Train/PolicyRatio/Std         │ 0.015624133870005608  │
# │ Train/LR                      │ 0.0002880000101868063 │
# │ Train/PolicyStd               │ 0.987421989440918     │
# │ TotalEnvSteps                 │ 2048.0                │
# │ Loss/Loss_pi                  │ -0.013572598807513714 │
# │ Loss/Loss_pi/Delta            │ -0.013572598807513714 │
# │ Value/Adv                     │ -0.10883629322052002  │
# │ Loss/Loss_reward_critic       │ 0.009244324639439583  │
# │ Loss/Loss_reward_critic/Delta │ 0.009244324639439583  │
# │ Value/reward                  │ -0.03484527766704559  │
# │ Time/Total                    │ 25.26022720336914     │
# │ Time/Rollout                  │ 12.441493034362793    │
# │ Time/Update                   │ 12.817733764648438    │
# │ Time/Epoch                    │ 25.259227752685547    │
# │ Time/FPS                      │ 81.07928466796875     │
# └───────────────────────────────┴───────────────────────┘
# Warning: trajectory cut off when rollout by epoch at 48.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                       ┃ Value                  ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                 │ -0.5105899572372437    │
# │ Metrics/EpCost                │ 0.0                    │
# │ Metrics/EpLen                 │ 1000.0                 │
# │ Train/Epoch                   │ 1.0                    │
# │ Train/Entropy                 │ 1.3987624645233154     │
# │ Train/KL                      │ 0.012238385155797005   │
# │ Train/StopIter                │ 40.0                   │
# │ Train/PolicyRatio/Mean        │ 0.996334433555603      │
# │ Train/PolicyRatio/Min         │ 0.9963344931602478     │
# │ Train/PolicyRatio/Max         │ 0.9963344931602478     │
# │ Train/PolicyRatio/Std         │ 0.0183890201151371     │
# │ Train/LR                      │ 0.00027600000612437725 │
# │ Train/PolicyStd               │ 0.9800329208374023     │
# │ TotalEnvSteps                 │ 4096.0                 │
# │ Loss/Loss_pi                  │ -0.012394366785883904  │
# │ Loss/Loss_pi/Delta            │ 0.0011782320216298103  │
# │ Value/Adv                     │ -0.11359758675098419   │
# │ Loss/Loss_reward_critic       │ 0.0017291067633777857  │
# │ Loss/Loss_reward_critic/Delta │ -0.007515217876061797  │
# │ Value/reward                  │ -0.011738033965229988  │
# │ Time/Total                    │ 50.032466888427734     │
# │ Time/Rollout                  │ 12.705947875976562     │
# │ Time/Update                   │ 12.038677215576172     │
# │ Time/Epoch                    │ 24.744625091552734     │
# │ Time/FPS                      │ 82.76544952392578      │
# └───────────────────────────────┴────────────────────────┘
# Warning: trajectory cut off when rollout by epoch at 48.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Early stopping at iter 31 due to reaching max kl
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                       ┃ Value                  ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                 │ -0.5384080410003662    │
# │ Metrics/EpCost                │ 0.0                    │
# │ Metrics/EpLen                 │ 1000.0                 │
# │ Train/Epoch                   │ 2.0                    │
# │ Train/Entropy                 │ 1.3927127122879028     │
# │ Train/KL                      │ 0.02069394290447235    │
# │ Train/StopIter                │ 31.0                   │
# │ Train/PolicyRatio/Mean        │ 0.9970620274543762     │
# │ Train/PolicyRatio/Min         │ 0.9970619678497314     │
# │ Train/PolicyRatio/Max         │ 0.9970619678497314     │
# │ Train/PolicyRatio/Std         │ 0.020371580496430397   │
# │ Train/LR                      │ 0.0002640000020619482  │
# │ Train/PolicyStd               │ 0.9744024872779846     │
# │ TotalEnvSteps                 │ 6144.0                 │
# │ Loss/Loss_pi                  │ -0.01676090434193611   │
# │ Loss/Loss_pi/Delta            │ -0.004366537556052208  │
# │ Value/Adv                     │ 0.13930422067642212    │
# │ Loss/Loss_reward_critic       │ 0.0002911170886363834  │
# │ Loss/Loss_reward_critic/Delta │ -0.0014379896747414023 │
# │ Value/reward                  │ 0.009503917768597603   │
# │ Time/Total                    │ 73.47379302978516      │
# │ Time/Rollout                  │ 13.429580688476562     │
# │ Time/Update                   │ 9.985848426818848      │
# │ Time/Epoch                    │ 23.415428161621094     │
# │ Time/FPS                      │ 87.46369934082031      │
# └───────────────────────────────┴────────────────────────┘
# Warning: trajectory cut off when rollout by epoch at 48.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                       ┃ Value                   ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                 │ -0.3831082284450531     │
# │ Metrics/EpCost                │ 0.0                     │
# │ Metrics/EpLen                 │ 1000.0                  │
# │ Train/Epoch                   │ 3.0                     │
# │ Train/Entropy                 │ 1.3808801174163818      │
# │ Train/KL                      │ 0.014169498346745968    │
# │ Train/StopIter                │ 40.0                    │
# │ Train/PolicyRatio/Mean        │ 1.0037285089492798      │
# │ Train/PolicyRatio/Min         │ 1.0037285089492798      │
# │ Train/PolicyRatio/Max         │ 1.0037285089492798      │
# │ Train/PolicyRatio/Std         │ 0.019438087940216064    │
# │ Train/LR                      │ 0.0002519999979995191   │
# │ Train/PolicyStd               │ 0.9635995030403137      │
# │ TotalEnvSteps                 │ 8192.0                  │
# │ Loss/Loss_pi                  │ -0.017553437501192093   │
# │ Loss/Loss_pi/Delta            │ -0.0007925331592559814  │
# │ Value/Adv                     │ -0.18588483333587646    │
# │ Loss/Loss_reward_critic       │ 0.00016702868742868304  │
# │ Loss/Loss_reward_critic/Delta │ -0.00012408840120770037 │
# │ Value/reward                  │ -0.005930560175329447   │
# │ Time/Total                    │ 100.55956268310547      │
# │ Time/Rollout                  │ 13.63131332397461       │
# │ Time/Update                   │ 13.430519104003906      │
# │ Time/Epoch                    │ 27.061832427978516      │
# │ Time/FPS                      │ 75.67854309082031       │
# └───────────────────────────────┴─────────────────────────┘

# %%
eg.analyze(parameter='algo_cfgs:gamma', values=None, compare_num=3, cost_limit=None)

# %%
# Single Python File
from omnisafe.common.statistics_tools import StatisticsTools

eg._statistical_tools.draw_graph(parameter='algo_cfgs:gamma', values=None, compare_num=3, cost_limit=None, show_image=True)
